# %% [markdown]
# # DATA CLEANING

# %% [markdown]
# # SORTING

# %%
import pandas as pd

# %%
df = pd.read_csv('nba.csv')

# %%
df.shape
# Out:
# (457, 9)

# %%
df = df.dropna()

# %%
df.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
df.sort_values('Name')
# Out:
#                     Name                    Team  Number Position   Age  \
# 152         Aaron Brooks           Chicago Bulls     0.0       PG  31.0
# 356         Aaron Gordon           Orlando Magic     0.0       PF  20.0
# 328       Aaron Harrison       Charlotte Hornets     9.0       SG  21.0
# 404        Adreian Payne  Minnesota Timberwolves    33.0       PF  25.0
# 312           Al Horford           Atlanta Hawks    15.0        C  30.0
# ..                   ...                     ...     ...      ...   ...
# 141  Willie Cauley-Stein        Sacramento Kings     0.0        C  22.0
# 25           Willie Reed           Brooklyn Nets    33.0       PF  26.0
# 386      Wilson Chandler          Denver Nuggets    21.0       SF  29.0
# 402          Zach LaVine  Minnesota Timberwolves     8.0       PG  21.0
# 271        Zach Randolph       Memphis Grizzlies    50.0       PF  34.0
#
#      Height  Weight         College      Salary
# 152     6-0   161.0          Oregon   2250000.0
# ...

# %%
pwd
# Out:
# 'C:\\Users\\hp\\OneDrive\\CLEAR\\3.A.PANDAS'

# %%
df = pd.read_csv(r'C:\\Users\\hp\\OneDrive\\CLEAR\\3.A.PANDAS\\nba.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      456 non-null    object
#  1   Team      456 non-null    object
#  2   Number    456 non-null    float64
#  3   Position  456 non-null    object
#  4   Age       456 non-null    float64
#  5   Height    456 non-null    object
#  6   Weight    456 non-null    float64
#  7   College   372 non-null    object
#  8   Salary    445 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
df.shape
# Out:
# (457, 9)

# %%
df.isnull().sum()
# Out:
# Name         1
# Team         1
# Number       1
# Position     1
# Age          1
# Height       1
# Weight       1
# College     85
# Salary      12
# dtype: int64

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (363, 9)

# %%
df.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
df.sort_values('Name')
# Out:
#                     Name                    Team  Number Position   Age  \
# 152         Aaron Brooks           Chicago Bulls     0.0       PG  31.0
# 356         Aaron Gordon           Orlando Magic     0.0       PF  20.0
# 328       Aaron Harrison       Charlotte Hornets     9.0       SG  21.0
# 404        Adreian Payne  Minnesota Timberwolves    33.0       PF  25.0
# 312           Al Horford           Atlanta Hawks    15.0        C  30.0
# ..                   ...                     ...     ...      ...   ...
# 141  Willie Cauley-Stein        Sacramento Kings     0.0        C  22.0
# 25           Willie Reed           Brooklyn Nets    33.0       PF  26.0
# 386      Wilson Chandler          Denver Nuggets    21.0       SF  29.0
# 402          Zach LaVine  Minnesota Timberwolves     8.0       PG  21.0
# 271        Zach Randolph       Memphis Grizzlies    50.0       PF  34.0
#
#      Height  Weight         College      Salary
# 152     6-0   161.0          Oregon   2250000.0
# ...

# %%
df.sort_values('Team')
# Out:
#                  Name                Team  Number Position   Age  Height  \
# 310  Tim Hardaway Jr.       Atlanta Hawks    10.0       SG  24.0  06-Jun
# 319        Mike Scott       Atlanta Hawks    32.0       PF  27.0  06-Aug
# 323       Jeff Teague       Atlanta Hawks     0.0       PG  27.0  06-Feb
# 316      Mike Muscala       Atlanta Hawks    31.0       PF  24.0  06-Nov
# 309     Kent Bazemore       Atlanta Hawks    24.0       SF  26.0  06-May
# ..                ...                 ...     ...      ...   ...     ...
# 380    Garrett Temple  Washington Wizards    17.0       SG  30.0  06-Jun
# 381   Marcus Thornton  Washington Wizards    15.0       SF  29.0  06-Apr
# 382         John Wall  Washington Wizards     2.0       PG  25.0  06-Apr
# 368     Alan Anderson  Washington Wizards     6.0       SG  33.0  06-Jun
# 370      Jared Dudley  Washington Wizards     1.0       SF  30.0  06-Jul
#
#      Weight         College      Salary
# 310   205.0        Michigan   1304520.0
# ...

# %%
df.sort_values('Name',ascending= False)
# Out:
#                     Name                    Team  Number Position   Age  \
# 271        Zach Randolph       Memphis Grizzlies    50.0       PF  34.0
# 402          Zach LaVine  Minnesota Timberwolves     8.0       PG  21.0
# 386      Wilson Chandler          Denver Nuggets    21.0       SF  29.0
# 25           Willie Reed           Brooklyn Nets    33.0       PF  26.0
# 141  Willie Cauley-Stein        Sacramento Kings     0.0        C  22.0
# ..                   ...                     ...     ...      ...   ...
# 312           Al Horford           Atlanta Hawks    15.0        C  30.0
# 404        Adreian Payne  Minnesota Timberwolves    33.0       PF  25.0
# 328       Aaron Harrison       Charlotte Hornets     9.0       SG  21.0
# 356         Aaron Gordon           Orlando Magic     0.0       PF  20.0
# 152         Aaron Brooks           Chicago Bulls     0.0       PG  31.0
#
#      Height  Weight         College      Salary
# 271  06-Sep   260.0  Michigan State   9638555.0
# ...

# %%
df.sort_values('College', ascending = False )
# Out:
#                    Name                  Team  Number Position   Age  Height  \
# 308          David West     San Antonio Spurs    30.0       PF  35.0  06-Sep
# 114     Larry Nance Jr.    Los Angeles Lakers     7.0       PF  23.0  06-Sep
# 145          Duje Dukan      Sacramento Kings    26.0       PF  24.0  06-Sep
# 331  Frank Kaminsky III     Charlotte Hornets    44.0        C  23.0     7-0
# 129           Jon Leuer          Phoenix Suns    30.0       PF  27.0  06-Oct
# ..                  ...                   ...     ...      ...   ...     ...
# 256         Jason Terry       Houston Rockets    31.0       SG  38.0  06-Feb
# 167       Channing Frye   Cleveland Cavaliers     9.0       PF  33.0  06-Nov
# 266      JaMychal Green     Memphis Grizzlies     0.0       PF  25.0  06-Sep
# 180         Mo Williams   Cleveland Cavaliers    52.0       PG  33.0  06-Jan
# 287          Alonzo Gee  New Orleans Pelicans    15.0       SF  29.0  06-Jun
#
#      Weight    College     Salary
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
df.sort_values('Age',ascending=False)
# Out:
#                 Name                   Team  Number Position   Age  Height  \
# 298       Tim Duncan      San Antonio Spurs    21.0        C  40.0  06-Nov
# 304     Andre Miller      San Antonio Spurs    24.0       PG  40.0  06-Mar
# 261     Vince Carter      Memphis Grizzlies    15.0       SG  39.0  06-Jun
# 101      Paul Pierce   Los Angeles Clippers    34.0       SF  38.0  06-Jul
# 420    Nazr Mohammed  Oklahoma City Thunder    13.0        C  38.0  06-Oct
# ..               ...                    ...     ...      ...   ...     ...
# 85      Kevon Looney  Golden State Warriors    36.0       SF  20.0  06-Sep
# 208     Myles Turner         Indiana Pacers    33.0       PF  20.0  06-Nov
# 192  Stanley Johnson        Detroit Pistons     3.0       SF  20.0  06-Jul
# 122     Devin Booker           Phoenix Suns     1.0       SG  19.0  06-Jun
# 226    Rashad Vaughn        Milwaukee Bucks    20.0       SG  19.0  06-Jun
#
#      Weight         College     Salary
# ...

# %%
df.sort_values('Weight')
# Out:
#                  Name                    Team  Number Position   Age  Height  \
# 152      Aaron Brooks           Chicago Bulls     0.0       PG  31.0     6-0
# 263      Bryce Cotton       Memphis Grizzlies     8.0       PG  23.0  06-Jan
# 286       Tim Frazier    New Orleans Pelicans     2.0       PG  25.0  06-Jan
# 183       Steve Blake         Detroit Pistons    22.0       PG  36.0  06-Mar
# 440     Brian Roberts  Portland Trail Blazers     2.0       PG  30.0  06-Jan
# ..                ...                     ...     ...      ...   ...     ...
# 143  DeMarcus Cousins        Sacramento Kings    15.0        C  25.0  06-Nov
# 117      Robert Sacre      Los Angeles Lakers    50.0        C  27.0     7-0
# 56      Jahlil Okafor      Philadelphia 76ers     8.0        C  20.0  06-Nov
# 23        Brook Lopez           Brooklyn Nets    11.0        C  28.0     7-0
# 188    Andre Drummond         Detroit Pistons     0.0        C  22.0  06-Nov
#
#      Weight      College      Salary
# ...

# %%
df.sort_values('Weight',ascending=False)
# Out:
#                  Name                    Team  Number Position   Age  Height  \
# 188    Andre Drummond         Detroit Pistons     0.0        C  22.0  06-Nov
# 23        Brook Lopez           Brooklyn Nets    11.0        C  28.0     7-0
# 56      Jahlil Okafor      Philadelphia 76ers     8.0        C  20.0  06-Nov
# 143  DeMarcus Cousins        Sacramento Kings    15.0        C  25.0  06-Nov
# 117      Robert Sacre      Los Angeles Lakers    50.0        C  27.0     7-0
# ..                ...                     ...     ...      ...   ...     ...
# 440     Brian Roberts  Portland Trail Blazers     2.0       PG  30.0  06-Jan
# 183       Steve Blake         Detroit Pistons    22.0       PG  36.0  06-Mar
# 286       Tim Frazier    New Orleans Pelicans     2.0       PG  25.0  06-Jan
# 263      Bryce Cotton       Memphis Grizzlies     8.0       PG  23.0  06-Jan
# 152      Aaron Brooks           Chicago Bulls     0.0       PG  31.0     6-0
#
#      Weight      College      Salary
# ...

# %%
df = pd.read_csv('nba.csv')

# %%
df.head(3)
# Out:
#             Name            Team  Number Position   Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0  06-Feb   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0  06-Jun   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0  06-May   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
df.sort_values(["Team","Age"],ignore_index=True).head(5)
# Out:
#                Name           Team  Number Position   Age  Height  Weight  \
# 0   Dennis Schroder  Atlanta Hawks    17.0       PG  22.0  06-Jan   172.0
# 1  Tim Hardaway Jr.  Atlanta Hawks    10.0       SG  24.0  06-Jun   205.0
# 2      Mike Muscala  Atlanta Hawks    31.0       PF  24.0  06-Nov   240.0
# 3   Lamar Patterson  Atlanta Hawks    13.0       SG  24.0  06-May   225.0
# 4    Walter Tavares  Atlanta Hawks    22.0        C  24.0  07-Mar   260.0
#
#       College     Salary
# 0         NaN  1763400.0
# 1    Michigan  1304520.0
# 2    Bucknell   947276.0
# 3  Pittsburgh   525093.0
# 4         NaN  1000000.0

# %%
df.sort_values(['College', 'Salary'],ascending=[True,False]).head(20)
# Out:
#                         Name                   Team  Number Position   Age  \
# 180              Mo Williams    Cleveland Cavaliers    52.0       PG  33.0
# 287               Alonzo Gee   New Orleans Pelicans    15.0       SF  29.0
# 266           JaMychal Green      Memphis Grizzlies     0.0       PF  25.0
# 83            Andre Iguodala  Golden State Warriors     9.0       SF  32.0
# 167            Channing Frye    Cleveland Cavaliers     9.0       PF  33.0
# 356             Aaron Gordon          Orlando Magic     0.0       PF  20.0
# 44          Derrick Williams        New York Knicks    23.0       PF  25.0
# 201              Jordan Hill         Indiana Pacers    27.0        C  28.0
# 212           Jerryd Bayless        Milwaukee Bucks    19.0       PG  27.0
# 192          Stanley Johnson        Detroit Pistons     3.0       SF  20.0
# 202             Solomon Hill         Indiana Pacers    44.0       SF  25.0
# ...

# %%
df.sort_values?

# %%
newdf = df.sort_values(['College','Team','Salary'],ascending=[True,True,False],ignore_index=True).head(20)

# %%
newdf
# Out:
#                        Name                   Team  Number Position   Age  \
# 0               Mo Williams    Cleveland Cavaliers    52.0       PG  33.0
# 1            JaMychal Green      Memphis Grizzlies     0.0       PF  25.0
# 2                Alonzo Gee   New Orleans Pelicans    15.0       SF  29.0
# 3   Rondae Hollis-Jefferson          Brooklyn Nets    24.0       SG  21.0
# 4             Channing Frye    Cleveland Cavaliers     9.0       PF  33.0
# 5         Richard Jefferson    Cleveland Cavaliers    24.0       SF  35.0
# 6           Stanley Johnson        Detroit Pistons     3.0       SF  20.0
# 7            Andre Iguodala  Golden State Warriors     9.0       SF  32.0
# 8               Jason Terry        Houston Rockets    31.0       SG  38.0
# 9               Jordan Hill         Indiana Pacers    27.0        C  28.0
# 10             Solomon Hill         Indiana Pacers    44.0       SF  25.0
# 11           Jerryd Bayless        Milwaukee Bucks    19.0       PG  27.0
# ...
