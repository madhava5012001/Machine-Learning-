# %%
import pandas as pd

# %%
df = pd.read_csv('fortune1000.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rank       1000 non-null   int64
#  1   Company    1000 non-null   object
#  2   Sector     1000 non-null   object
#  3   Industry   1000 non-null   object
#  4   Location   1000 non-null   object
#  5   Revenue    1000 non-null   int64
#  6   Profits    1000 non-null   int64
#  7   Employees  1000 non-null   int64
# dtypes: int64(4), object(4)
# memory usage: 62.6+ KB

# %%
df.head(4)
# Out:
#    Rank             Company      Sector  \
# 0     1             Walmart   Retailing
# 1     2         Exxon Mobil      Energy
# 2     3               Apple  Technology
# 3     4  Berkshire Hathaway  Financials
#
#                                    Industry         Location  Revenue  \
# 0                     General Merchandisers  Bentonville, AR   482130
# 1                        Petroleum Refining       Irving, TX   246204
# 2               Computers, Office Equipment    Cupertino, CA   233715
# 3  Insurance: Property and Casualty (Stock)        Omaha, NE   210821
#
#    Profits  Employees
# 0    14694    2300000
# 1    16150      75600
# 2    53394     110000
# 3    24083     331000

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # GROUP BY

# %%
groupedSectors = df.groupby('Sector')

# %%
type(Sectors)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
len(groupedSectors)
# Out:
# 21

# %%
df.columns
# Out:
# Index(['Rank', 'Company', 'Sector', 'Industry', 'Location', 'Revenue',
#        'Profits', 'Employees'],
#       dtype='object')

# %%
df.head(3)
# Out:
#    Rank      Company      Sector                     Industry  \
# 0     1      Walmart   Retailing        General Merchandisers
# 1     2  Exxon Mobil      Energy           Petroleum Refining
# 2     3        Apple  Technology  Computers, Office Equipment
#
#           Location  Revenue  Profits  Employees
# 0  Bentonville, AR   482130    14694    2300000
# 1       Irving, TX   246204    16150      75600
# 2    Cupertino, CA   233715    53394     110000

# %%
groupedSectors

# %%
groupedSectors.size()
# Out:
# Sector
# Aerospace & Defense              20
# Apparel                          15
# Business Services                51
# Chemicals                        30
# Energy                          122
# Engineering & Construction       26
# Financials                      139
# Food and Drug Stores             15
# Food, Beverages & Tobacco        43
# Health Care                      75
# Hotels, Resturants & Leisure     25
# Household Products               28
# Industrials                      46
# Materials                        43
# Media                            25
# Motor Vehicles & Parts           24
# Retailing                        80
# Technology                      102
# Telecommunications               15
# Transportation                   36
# Wholesalers                      40
# dtype: int64

# %%
df['Sector'].value_counts()
# Out:
# Financials                      139
# Energy                          122
# Technology                      102
# Retailing                        80
# Health Care                      75
# Business Services                51
# Industrials                      46
# Food, Beverages & Tobacco        43
# Materials                        43
# Wholesalers                      40
# Transportation                   36
# Chemicals                        30
# Household Products               28
# Engineering & Construction       26
# Hotels, Resturants & Leisure     25
# Media                            25
# Motor Vehicles & Parts           24
# Aerospace & Defense              20
# Apparel                          15
# Telecommunications               15
# Food and Drug Stores             15
# Name: Sector, dtype: int64

# %%
groupedIndustry = df.groupby('Industry')

# %%
groupedIndustry.size().head(40)
# Out:
# Industry
# Advertising, marketing                        2
# Aerospace and Defense                        20
# Airlines                                      9
# Apparel                                      15
# Automotive Retailing, Services               10
# Beverages                                     9
# Building Materials, Glass                     7
# Chemicals                                    30
# Commercial Banks                             28
# Computer Peripherals                          4
# Computer Software                            14
# Computers, Office Equipment                   7
# Construction and Farm Machinery               9
# Diversified Financials                       15
# Diversified Outsourcing Services             14
# Education                                     3
# Electronics, Electrical Equip.               13
# Energy                                       14
# Engineering, Construction                    14
# ...

# %%
df['Industry'].value_counts()
# Out:
# Specialty Retailers: Other                  42
# Utilities: Gas and Electric                 41
# Chemicals                                   30
# Mining, Crude-Oil Production                28
# Insurance: Property and Casualty (Stock)    28
#                                             ..
# Railroads                                    5
# Computer Peripherals                         4
# Education                                    3
# Mail, Package, and Freight Delivery          2
# Advertising, marketing                       2
# Name: Industry, Length: 73, dtype: int64

# %%
groupedSectors.max()
# Out:
#                               Rank                 Company  \
# Sector
# Aerospace & Defense            987                Woodward
# Apparel                        917    Wolverine World Wide
# Business Services              993           Western Union
# Chemicals                      949       Westlake Chemical
# Energy                         997             Xcel Energy
# Engineering & Construction     994            Tutor Perini
# Financials                     996          Zions Bancorp.
# Food and Drug Stores           928      Whole Foods Market
# Food, Beverages & Tobacco      954         WhiteWave Foods
# Health Care                    978         inVentiv Health
# Hotels, Resturants & Leisure   999              Yum Brands
# Household Products             992           Vista Outdoor
# Industrials                   1000      Zebra Technologies
# Materials                      986  Worthington Industries
# Media                          989             iHeartMedia
# ...

# %%
groupedIndustry.max()
# Out:
#                                                Rank  \
# Industry
# Advertising, marketing                          355
# Aerospace and Defense                           987
# Airlines                                        933
# Apparel                                         917
# Automotive Retailing, Services                  511
# ...                                             ...
# Waste Management                                939
# Wholesalers: Diversified                        991
# Wholesalers: Electronics and Office Equipment   685
# Wholesalers: Food and Grocery                   351
# Wholesalers: Health Care                        559
#
#                                                                    Company  \
# Industry
# Advertising, marketing                                       Omnicom Group
# Aerospace and Defense                                             Woodward
# Airlines                                       United Continental Holdings
# ...

# %%
groupedIndustry.min()
# Out:
#                                                Rank                  Company  \
# Industry
# Advertising, marketing                          186        Interpublic Group
# Aerospace and Defense                            24            B/E Aerospace
# Airlines                                         67         Alaska Air Group
# Apparel                                          91                 Carter’s
# Automotive Retailing, Services                  136  Asbury Automotive Group
# ...                                             ...                      ...
# Waste Management                                221            Clean Harbors
# Wholesalers: Diversified                         92                   Airgas
# Wholesalers: Electronics and Office Equipment    64        Arrow Electronics
# Wholesalers: Food and Grocery                    57        Core-Mark Holding
# Wholesalers: Health Care                          5        AmerisourceBergen
#
# ...

# %%
Sectors.sum()
# Out:
#                                Rank  Revenue  Profits  Employees
# Sector
# Aerospace & Defense            8870   357940    28742     968057
# Apparel                        8757    95968     8236     346397
# Business Services             31074   272195    28227    1361050
# Chemicals                     15928   243897    22628     463651
# Energy                        62199  1517809   -73447    1188927
# Engineering & Construction    15147   153983     5304     406708
# Financials                    63566  2217159   260209    3359948
# Food and Drug Stores           6429   483769    16759    1395398
# Food, Beverages & Tobacco     18629   555967    51417    1211632
# Health Care                   31770  1614707   106114    2678289
# Hotels, Resturants & Leisure  14039   169546    20697    2484245
# Household Products            15749   234737    14428     646038
# Industrials                   26988   497581    20764    1545229
# ...

# %%
groupedIndustry.sum()
# Out:
#                                                 Rank  Revenue  Profits  \
# Industry
# Advertising, marketing                           541    22748     1549
# Aerospace and Defense                           8870   357940    28742
# Airlines                                        3747   158948    23800
# Apparel                                         8757    95968     8236
# Automotive Retailing, Services                  2883   113823     2550
# ...                                              ...      ...      ...
# Waste Management                                2884    30454     1718
# Wholesalers: Diversified                       12922   176138     5193
# Wholesalers: Electronics and Office Equipment   2241   147906     1857
# Wholesalers: Food and Grocery                   1367   111774     1166
# Wholesalers: Health Care                        1156   444512     3361
#
#                                                Employees
# Industry
# ...

# %%
groupedIndustry['Revenue'].sum().head(20)
# Out:
# Industry
# Advertising, marketing               22748
# Aerospace and Defense               357940
# Airlines                            158948
# Apparel                              95968
# Automotive Retailing, Services      113823
# Beverages                            79396
# Building Materials, Glass            25615
# Chemicals                           243897
# Commercial Banks                    623669
# Computer Peripherals                 48950
# Computer Software                   179112
# Computers, Office Equipment         353781
# Construction and Farm Machinery     120612
# Diversified Financials              327075
# Diversified Outsourcing Services     64829
# Education                             7485
# Electronics, Electrical Equip.      119365
# Energy                               67749
# Engineering, Construction            99774
# Entertainment                       186276
# Name: Revenue, dtype: int64

# %%
groupedIndustry['Employees'].sum()
# Out:
# Industry
# Advertising, marketing                           124100
# Aerospace and Defense                            968057
# Airlines                                         391601
# Apparel                                          346397
# Automotive Retailing, Services                   174974
#                                                   ...
# Waste Management                                 119199
# Wholesalers: Diversified                         233831
# Wholesalers: Electronics and Office Equipment    166661
# Wholesalers: Food and Grocery                    115905
# Wholesalers: Health Care                         156000
# Name: Employees, Length: 73, dtype: int64

# %%
df.head(10)
# Out:
#    Rank             Company                  Sector  \
# 0     1             Walmart               Retailing
# 1     2         Exxon Mobil                  Energy
# 2     3               Apple              Technology
# 3     4  Berkshire Hathaway              Financials
# 4     5            McKesson             Health Care
# 5     6  UnitedHealth Group             Health Care
# 6     7          CVS Health    Food and Drug Stores
# 7     8      General Motors  Motor Vehicles & Parts
# 8     9          Ford Motor  Motor Vehicles & Parts
# 9    10                AT&T      Telecommunications
#
#                                    Industry           Location  Revenue  \
# 0                     General Merchandisers    Bentonville, AR   482130
# 1                        Petroleum Refining         Irving, TX   246204
# 2               Computers, Office Equipment      Cupertino, CA   233715
# 3  Insurance: Property and Casualty (Stock)          Omaha, NE   210821
# ...

# %%
pd.set_option('display.max_rows', 500)

# %%
groupedIndustry['Revenue'].mean()
# Out:
# Industry
# Advertising, marketing                            11374.000000
# Aerospace and Defense                             17897.000000
# Airlines                                          17660.888889
# Apparel                                            6397.866667
# Automotive Retailing, Services                    11382.300000
# Beverages                                          8821.777778
# Building Materials, Glass                          3659.285714
# Chemicals                                          8129.900000
# Commercial Banks                                  22273.892857
# Computer Peripherals                              12237.500000
# Computer Software                                 12793.714286
# Computers, Office Equipment                       50540.142857
# Construction and Farm Machinery                   13401.333333
# Diversified Financials                            21805.000000
# Diversified Outsourcing Services                   4630.642857
# ...

# %%
groupedIndustry['Revenue','Employees'].mean().head(20)
# Out:
# <ipython-input-58-5af9e2cff407>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   groupedIndustry['Revenue','Employees'].mean().head(20)
#                                        Revenue     Employees
# Industry
# Advertising, marketing            11374.000000  62050.000000
# Aerospace and Defense             17897.000000  48402.850000
# Airlines                          17660.888889  43511.222222
# Apparel                            6397.866667  23093.133333
# Automotive Retailing, Services    11382.300000  17497.400000
# Beverages                          8821.777778  22123.000000
# Building Materials, Glass          3659.285714  10283.714286
# Chemicals                          8129.900000  15455.033333
# Commercial Banks                  22273.892857  54965.142857
# Computer Peripherals              12237.500000  43814.750000
# Computer Software                 12793.714286  27771.142857
# ...
