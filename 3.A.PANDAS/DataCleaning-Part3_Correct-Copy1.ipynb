# %% [markdown]
# # GROUPBY

# %% [raw]
# A groupby operation involves some combination of splitting the object, applying a function,
# and combining the results.
# This can be used to group large amounts of data and compute operations on these groups.

# %%
import pandas as pd

# %%
df = pd.read_csv('fortune1000.csv')

# %%
df.head(3)
# Out:
#    Rank      Company      Sector                     Industry  \
# 0     1      Walmart   Retailing        General Merchandisers
# 1     2  Exxon Mobil      Energy           Petroleum Refining
# 2     3        Apple  Technology  Computers, Office Equipment
#
#           Location  Revenue  Profits  Employees
# 0  Bentonville, AR   482130    14694    2300000
# 1       Irving, TX   246204    16150      75600
# 2    Cupertino, CA   233715    53394     110000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rank       1000 non-null   int64
#  1   Company    1000 non-null   object
#  2   Sector     1000 non-null   object
#  3   Industry   1000 non-null   object
#  4   Location   1000 non-null   object
#  5   Revenue    1000 non-null   int64
#  6   Profits    1000 non-null   int64
#  7   Employees  1000 non-null   int64
# dtypes: int64(4), object(4)
# memory usage: 62.6+ KB

# %%
pwd
# Out:
# 'C:\\Users\\hp\\OneDrive\\CLEAR\\3.A.PANDAS'

# %%
df.head(30)
# Out:
#     Rank                   Company                  Sector  \
# 0      1                   Walmart               Retailing
# 1      2               Exxon Mobil                  Energy
# 2      3                     Apple              Technology
# 3      4        Berkshire Hathaway              Financials
# 4      5                  McKesson             Health Care
# 5      6        UnitedHealth Group             Health Care
# 6      7                CVS Health    Food and Drug Stores
# 7      8            General Motors  Motor Vehicles & Parts
# 8      9                Ford Motor  Motor Vehicles & Parts
# 9     10                      AT&T      Telecommunications
# 10    11          General Electric             Industrials
# 11    12         AmerisourceBergen             Health Care
# 12    13                   Verizon      Telecommunications
# 13    14                   Chevron                  Energy
# 14    15                    Costco               Retailing
# ...

# %%
df = df.drop(columns='Rank')

# %%
df.head(3)
# Out:
#        Company      Sector                     Industry         Location  \
# 0      Walmart   Retailing        General Merchandisers  Bentonville, AR
# 1  Exxon Mobil      Energy           Petroleum Refining       Irving, TX
# 2        Apple  Technology  Computers, Office Equipment    Cupertino, CA
#
#    Revenue  Profits  Employees
# 0   482130    14694    2300000
# 1   246204    16150      75600
# 2   233715    53394     110000

# %%
sectors = df.groupby("Sector")

# %%
# Data type is changed

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
sectors = df.groupby("Sector")

# Group of Data frame bundled towards one object

# %%
type(sectors)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
type(sectors)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
len(df)
# Out:
# 1000

# %%
len(sectors)
# Out:
# 21

# %%
sectors

# %%
len(df)
# Out:
# 1000

# %%
len(sectors)
# Out:
# 21

# %%
df.head(3)
# Out:
#        Company      Sector                     Industry         Location  \
# 0      Walmart   Retailing        General Merchandisers  Bentonville, AR
# 1  Exxon Mobil      Energy           Petroleum Refining       Irving, TX
# 2        Apple  Technology  Computers, Office Equipment    Cupertino, CA
#
#    Revenue  Profits  Employees
# 0   482130    14694    2300000
# 1   246204    16150      75600
# 2   233715    53394     110000

# %%
df['Sector'].value_counts()
# Out:
# Financials                      139
# Energy                          122
# Technology                      102
# Retailing                        80
# Health Care                      75
# Business Services                51
# Industrials                      46
# Materials                        43
# Food, Beverages & Tobacco        43
# Wholesalers                      40
# Transportation                   36
# Chemicals                        30
# Household Products               28
# Engineering & Construction       26
# Media                            25
# Hotels, Resturants & Leisure     25
# Motor Vehicles & Parts           24
# Aerospace & Defense              20
# Food and Drug Stores             15
# Apparel                          15
# Telecommunications               15
# Name: Sector, dtype: int64

# %%
df.columns
# Out:
# Index(['Company', 'Sector', 'Industry', 'Location', 'Revenue', 'Profits',
#        'Employees'],
#       dtype='object')

# %%
negrbtech = df.groupby("Industry")

# %%
len(negrbtech)
# Out:
# 73

# %%
pd.set_option('display.max_rows',None)

# %%
negrbtech.size().head(80)
# Out:
# Industry
# Advertising, marketing                             2
# Aerospace and Defense                             20
# Airlines                                           9
# Apparel                                           15
# Automotive Retailing, Services                    10
# Beverages                                          9
# Building Materials, Glass                          7
# Chemicals                                         30
# Commercial Banks                                  28
# Computer Peripherals                               4
# Computer Software                                 14
# Computers, Office Equipment                        7
# Construction and Farm Machinery                    9
# Diversified Financials                            15
# Diversified Outsourcing Services                  14
# Education                                          3
# Electronics, Electrical Equip.                    13
# ...

# %% [markdown]
# 21 unique  sectors are aviable

# %%
df["Sector"].nunique()
# Out:
# 21

# %%
sectors.size()
# Out:
# Sector
# Aerospace & Defense              20
# Apparel                          15
# Business Services                51
# Chemicals                        30
# Energy                          122
# Engineering & Construction       26
# Financials                      139
# Food and Drug Stores             15
# Food, Beverages & Tobacco        43
# Health Care                      75
# Hotels, Resturants & Leisure     25
# Household Products               28
# Industrials                      46
# Materials                        43
# Media                            25
# Motor Vehicles & Parts           24
# Retailing                        80
# Technology                      102
# Telecommunications               15
# Transportation                   36
# Wholesalers                      40
# dtype: int64

# %% [markdown]
# Retuns number of rows availble in each category
# for that particular sub catebory

# %%
df["Sector"].value_counts()
# Out:
# Financials                      139
# Energy                          122
# Technology                      102
# Retailing                        80
# Health Care                      75
# Business Services                51
# Industrials                      46
# Food, Beverages & Tobacco        43
# Materials                        43
# Wholesalers                      40
# Transportation                   36
# Chemicals                        30
# Household Products               28
# Engineering & Construction       26
# Hotels, Resturants & Leisure     25
# Media                            25
# Motor Vehicles & Parts           24
# Aerospace & Defense              20
# Apparel                          15
# Food and Drug Stores             15
# Telecommunications               15
# Name: Sector, dtype: int64

# %% [markdown]
# Retuns higher to lower values

# %%
sectors.first()
# Out:
#                                              Company  \
# Sector
# Aerospace & Defense                           Boeing
# Apparel                                         Nike
# Business Services                      ManpowerGroup
# Chemicals                               Dow Chemical
# Energy                                   Exxon Mobil
# Engineering & Construction                     Fluor
# Financials                        Berkshire Hathaway
# Food and Drug Stores                      CVS Health
# Food, Beverages & Tobacco     Archer Daniels Midland
# Health Care                                 McKesson
# Hotels, Resturants & Leisure              McDonald’s
# Household Products                  Procter & Gamble
# Industrials                         General Electric
# Materials                                      Alcoa
# Media                                         Disney
# Motor Vehicles & Parts                General Motors
# ...

# %%
df.head(3)
# Out:
#        Company      Sector                     Industry         Location  \
# 0      Walmart   Retailing        General Merchandisers  Bentonville, AR
# 1  Exxon Mobil      Energy           Petroleum Refining       Irving, TX
# 2        Apple  Technology  Computers, Office Equipment    Cupertino, CA
#
#    Revenue  Profits  Employees
# 0   482130    14694    2300000
# 1   246204    16150      75600
# 2   233715    53394     110000

# %% [markdown]
# Retuns first line of each sector

# %%
sectors.last()
# Out:
#                                                         Company  \
# Sector
# Aerospace & Defense                       Delta Tucker Holdings
# Apparel                                                   Guess
# Business Services                         DeVry Education Group
# Chemicals                                           H.B. Fuller
# Energy                                Portland General Electric
# Engineering & Construction                         MDC Holdings
# Financials                           New York Community Bancorp
# Food and Drug Stores                                     Fred’s
# Food, Beverages & Tobacco            Alliance One International
# Health Care                                  Providence Service
# Hotels, Resturants & Leisure                            Wendy’s
# Household Products                                       Revlon
# Industrials                                   Briggs & Stratton
# ...

# %% [markdown]
# Returns last line of each sector

# %%
#sectors.groups

# Groups provides us dictionary
# Out:
# {'Aerospace & Defense': Int64Index([ 24,  45,  60,  88, 118, 120, 209, 245, 282, 378, 389, 490, 560,
#              605, 785, 788, 836, 903, 958, 987],
#             dtype='int64', name='Rank'),
#  'Apparel': Int64Index([91, 231, 340, 354, 448, 547, 575, 597, 683, 695, 726, 794, 877,
#              882, 917],
#             dtype='int64', name='Rank'),
#  'Business Services': Int64Index([144, 186, 199, 204, 221, 248, 249, 294, 307, 312, 355, 392, 404,
#              440, 467, 468, 481, 485, 492, 503, 545, 626, 635, 652, 677, 694,
#              714, 729, 734, 735, 737, 744, 767, 776, 777, 783, 791, 792, 796,
#              801, 803, 816, 819, 820, 869, 870, 886, 939, 951, 952, 993],
#             dtype='int64', name='Rank'),
#  'Chemicals': Int64Index([ 56, 101, 182, 189, 206, 253, 262, 277, 288, 296, 316, 538, 549,
#              555, 566, 580, 613, 624, 654, 668, 717, 720, 724, 758, 761, 829,
#              865, 898, 934, 949],
#             dtype='int64', name='Rank'),
# ...

# %%
sectors

# %% [markdown]
# # get_group() Method

# %%
df.head(3)
# Out:
#    Rank      Company      Sector                     Industry  \
# 0     1      Walmart   Retailing        General Merchandisers
# 1     2  Exxon Mobil      Energy           Petroleum Refining
# 2     3        Apple  Technology  Computers, Office Equipment
#
#           Location  Revenue  Profits  Employees
# 0  Bentonville, AR   482130    14694    2300000
# 1       Irving, TX   246204    16150      75600
# 2    Cupertino, CA   233715    53394     110000

# %%
sectors.get_group("Energy")
# Out:
#                        Company                      Industry         Location  \
# 1                  Exxon Mobil            Petroleum Refining       Irving, TX
# 13                     Chevron            Petroleum Refining    San Ramon, CA
# 29                 Phillips 66            Petroleum Refining      Houston, TX
# 31               Valero Energy            Petroleum Refining  San Antonio, TX
# 41          Marathon Petroleum            Petroleum Refining      Findlay, OH
# ..                         ...                           ...              ...
# 980                 WPX Energy  Mining, Crude-Oil Production        Tulsa, OK
# 982   Adams Resources & Energy            Petroleum Refining      Houston, TX
# 994                  EP Energy  Mining, Crude-Oil Production      Houston, TX
# 996  Portland General Electric   Utilities: Gas and Electric     Portland, OR
# 997  Portland General Electric   Utilities: Gas and Electric     Portland, OR
#
#      Revenue  Profits  Employees
# ...

# %%
sectors.get_group("Technology")
# Out:
#                    Company                                    Industry  \
# 2                    Apple                 Computers, Office Equipment
# 17              Amazon.com             Internet Services and Retailing
# 19                      HP                 Computers, Office Equipment
# 24               Microsoft                           Computer Software
# 30                     IBM             Information Technology Services
# ..                     ...                                         ...
# 969      Rackspace Hosting             Internet Services and Retailing
# 970       VeriFone Systems                 Computers, Office Equipment
# 974   Super Micro Computer                 Computers, Office Equipment
# 983  Nuance Communications                           Computer Software
# 989            F5 Networks  Network and Other Communications Equipment
#
#             Location  Revenue  Profits  Employees
# 2      Cupertino, CA   233715    53394     110000
# ...

# %%
sectors.get_group("Apparel")
# Out:
#                   Company Industry             Location  Revenue  Profits  \
# 90                   Nike  Apparel        Beaverton, OR    30601     3273
# 230                    VF  Apparel       Greensboro, NC    12377     1232
# 339                   PVH  Apparel         New York, NY     8020      572
# 353          Ralph Lauren  Apparel         New York, NY     7620      702
# 447           Hanesbrands  Apparel    Winston-Salem, NC     5732      429
# 546          Levi Strauss  Apparel    San Francisco, CA     4495      209
# 574                 Coach  Apparel         New York, NY     4192      402
# 596          Under Armour  Apparel        Baltimore, MD     3963      233
# 682          Fossil Group  Apparel       Richardson, TX     3229      221
# 694       Skechers U.S.A.  Apparel  Manhattan Beach, CA     3159      232
# 725              Carter’s  Apparel          Atlanta, GA     3014      238
# 793  Wolverine World Wide  Apparel         Rockford, MI     2692      123
# ...

# %%
df["Sector"] == "Apparel"
df[df["Sector"] == "Apparel"]
# Out:
#                   Company   Sector Industry             Location  Revenue  \
# 90                   Nike  Apparel  Apparel        Beaverton, OR    30601
# 230                    VF  Apparel  Apparel       Greensboro, NC    12377
# 339                   PVH  Apparel  Apparel         New York, NY     8020
# 353          Ralph Lauren  Apparel  Apparel         New York, NY     7620
# 447           Hanesbrands  Apparel  Apparel    Winston-Salem, NC     5732
# 546          Levi Strauss  Apparel  Apparel    San Francisco, CA     4495
# 574                 Coach  Apparel  Apparel         New York, NY     4192
# 596          Under Armour  Apparel  Apparel        Baltimore, MD     3963
# 682          Fossil Group  Apparel  Apparel       Richardson, TX     3229
# 694       Skechers U.S.A.  Apparel  Apparel  Manhattan Beach, CA     3159
# 725              Carter’s  Apparel  Apparel          Atlanta, GA     3014
# 793  Wolverine World Wide  Apparel  Apparel         Rockford, MI     2692
# ...

# %% [markdown]
# # Gropup By OBJECT

# %%
sectors.min()
# Out:
#                                                     Company  \
# Sector
# Aerospace & Defense                           B/E Aerospace
# Apparel                                            Carter’s
# Business Services                            ABM Industries
# Chemicals                                       A. Schulman
# Energy                                                  AES
# Engineering & Construction                            AECOM
# Financials                                              AIG
# Food and Drug Stores                             CVS Health
# Food, Beverages & Tobacco        Alliance One International
# Health Care                                          AbbVie
# Hotels, Resturants & Leisure                Bloomin’ Brands
# Household Products                            Avon Products
# Industrials                                              3M
# Materials                            A-Mark Precious Metals
# ...

# %%
# Returns Sectors as index labels 

#Returns Aplhabetical ranking in desecding

# %%
sectors.max()
# Out:
#                                              Company  \
# Sector
# Aerospace & Defense                         Woodward
# Apparel                         Wolverine World Wide
# Business Services                      Western Union
# Chemicals                          Westlake Chemical
# Energy                                   Xcel Energy
# Engineering & Construction              Tutor Perini
# Financials                            Zions Bancorp.
# Food and Drug Stores              Whole Foods Market
# Food, Beverages & Tobacco            WhiteWave Foods
# Health Care                          inVentiv Health
# Hotels, Resturants & Leisure              Yum Brands
# Household Products                     Vista Outdoor
# Industrials                       Zebra Technologies
# Materials                     Worthington Industries
# Media                                    iHeartMedia
# Motor Vehicles & Parts               Wabash National
# ...

# %%
sectors["Revenue"].max()
# Out:
# Sector
# Aerospace & Defense              96114
# Apparel                          30601
# Business Services                19330
# Chemicals                        48778
# Energy                          246204
# Engineering & Construction       18114
# Financials                      210821
# Food and Drug Stores            153290
# Food, Beverages & Tobacco        67702
# Health Care                     181241
# Hotels, Resturants & Leisure     25413
# Household Products               78756
# Industrials                     140389
# Materials                        22534
# Media                            52465
# Motor Vehicles & Parts          152356
# Retailing                       482130
# Technology                      233715
# Telecommunications              146801
# Transportation                   58363
# Wholesalers                      48681
# Name: Revenue, dtype: int64

# %%
# Returns Sectors as index labels 

#Returns Aplhabetical ranking in ascending

# %%
sectors.sum()

#Returns sum of Revenue of Aerospace
# Out:
#                               Revenue  Profits  Employees
# Sector
# Aerospace & Defense            357940    28742     968057
# Apparel                         95968     8236     346397
# Business Services              272195    28227    1361050
# Chemicals                      243897    22628     463651
# Energy                        1517809   -73447    1188927
# Engineering & Construction     153983     5304     406708
# Financials                    2217159   260209    3359948
# Food and Drug Stores           483769    16759    1395398
# Food, Beverages & Tobacco      555967    51417    1211632
# Health Care                   1614707   106114    2678289
# Hotels, Resturants & Leisure   169546    20697    2484245
# Household Products             234737    14428     646038
# Industrials                    497581    20764    1545229
# Materials                      259145     4428     638123
# Media                          220764    24347     550314
# ...

# %%
sectors.mean()
# Out:
#                                    Revenue      Profits     Employees
# Sector
# Aerospace & Defense           17897.000000  1437.100000  48402.850000
# Apparel                        6397.866667   549.066667  23093.133333
# Business Services              5337.156863   553.470588  26687.254902
# Chemicals                      8129.900000   754.266667  15455.033333
# Energy                        12441.057377  -602.024590   9745.303279
# Engineering & Construction     5922.423077   204.000000  15642.615385
# Financials                    15950.784173  1872.007194  24172.287770
# Food and Drug Stores          32251.266667  1117.266667  93026.533333
# Food, Beverages & Tobacco     12929.465116  1195.744186  28177.488372
# Health Care                   21529.426667  1414.853333  35710.520000
# Hotels, Resturants & Leisure   6781.840000   827.880000  99369.800000
# Household Products             8383.464286   515.285714  23072.785714
# ...

# %%
df.columns
# Out:
# Index(['Company', 'Sector', 'Industry', 'Location', 'Revenue', 'Profits',
#        'Employees'],
#       dtype='object')

# %%
#Another method

sectors.get_group("Apparel")["Revenue"].sum()
# Out:
# 95968

# %%
sectors.get_group("Apparel")["Revenue"].max()
# Out:
# 30601

# %%
sectors.get_group("Energy")['Revenue'].sum()
# Out:
# 1517809

# %%
# Out:
# array(['General Merchandisers', 'Petroleum Refining',
#        'Computers, Office Equipment',
#        'Insurance: Property and Casualty (Stock)',
#        'Wholesalers: Health Care',
#        'Health Care: Insurance and Managed Care', 'Food and Drug Stores',
#        'Motor Vehicles and Parts', 'Telecommunications',
#        'Industrial Machinery', 'Specialty Retailers: Other',
#        'Diversified Financials', 'Internet Services and Retailing',
#        'Health Care: Pharmacy and Other Services', 'Commercial Banks',
#        'Aerospace and Defense', 'Computer Software',
#        'Information Technology Services',
#        'Household and Personal Products',
#        'Insurance: Property and Casualty (Mutual)', 'Pharmaceuticals',
#        'Insurance: Life, Health (stock)', 'Food Production',
#        'Food Consumer Products', 'Mail, Package, and Freight Delivery',
#        'Semiconductors and Other Electronic Components', 'Entertainment',
# ...

# %%
df.head(3)
# Out:
#        Company      Sector                     Industry         Location  \
# 0      Walmart   Retailing        General Merchandisers  Bentonville, AR
# 1  Exxon Mobil      Energy           Petroleum Refining       Irving, TX
# 2        Apple  Technology  Computers, Office Equipment    Cupertino, CA
#
#    Revenue  Profits  Employees
# 0   482130    14694    2300000
# 1   246204    16150      75600
# 2   233715    53394     110000

# %%
sectors.get_group("Energy")
# Out:
#                        Company                      Industry         Location  \
# 1                  Exxon Mobil            Petroleum Refining       Irving, TX
# 13                     Chevron            Petroleum Refining    San Ramon, CA
# 29                 Phillips 66            Petroleum Refining      Houston, TX
# 31               Valero Energy            Petroleum Refining  San Antonio, TX
# 41          Marathon Petroleum            Petroleum Refining      Findlay, OH
# ..                         ...                           ...              ...
# 980                 WPX Energy  Mining, Crude-Oil Production        Tulsa, OK
# 982   Adams Resources & Energy            Petroleum Refining      Houston, TX
# 994                  EP Energy  Mining, Crude-Oil Production      Houston, TX
# 996  Portland General Electric   Utilities: Gas and Electric     Portland, OR
# 997  Portland General Electric   Utilities: Gas and Electric     Portland, OR
#
#      Revenue  Profits  Employees
# ...

# %%
df.head(3)
# Out:
#        Company      Sector                     Industry         Location  \
# 0      Walmart   Retailing        General Merchandisers  Bentonville, AR
# 1  Exxon Mobil      Energy           Petroleum Refining       Irving, TX
# 2        Apple  Technology  Computers, Office Equipment    Cupertino, CA
#
#    Revenue  Profits  Employees
# 0   482130    14694    2300000
# 1   246204    16150      75600
# 2   233715    53394     110000

# %%
 df.groupby("Industry")

# %%
ind.get_group('Petroleum Refining')['Employees'].sum()
# Out:
# 244880

# %%
df
# Out:
#                         Company                        Sector  \
# 0                       Walmart                     Retailing
# 1                   Exxon Mobil                        Energy
# 2                         Apple                    Technology
# 3            Berkshire Hathaway                    Financials
# 4                      McKesson                   Health Care
# ..                          ...                           ...
# 995  New York Community Bancorp                    Financials
# 996   Portland General Electric                        Energy
# 997   Portland General Electric                        Energy
# 998                     Wendy’s  Hotels, Resturants & Leisure
# 999           Briggs & Stratton                   Industrials
#
#                                      Industry           Location  Revenue  \
# 0                       General Merchandisers    Bentonville, AR   482130
# ...

# %%
sectors.mean()
# Out:
#                                    Revenue      Profits     Employees
# Sector
# Aerospace & Defense           17897.000000  1437.100000  48402.850000
# Apparel                        6397.866667   549.066667  23093.133333
# Business Services              5337.156863   553.470588  26687.254902
# Chemicals                      8129.900000   754.266667  15455.033333
# Energy                        12441.057377  -602.024590   9745.303279
# Engineering & Construction     5922.423077   204.000000  15642.615385
# Financials                    15950.784173  1872.007194  24172.287770
# Food and Drug Stores          32251.266667  1117.266667  93026.533333
# Food, Beverages & Tobacco     12929.465116  1195.744186  28177.488372
# Health Care                   21529.426667  1414.853333  35710.520000
# Hotels, Resturants & Leisure   6781.840000   827.880000  99369.800000
# Household Products             8383.464286   515.285714  23072.785714
# ...

# %%
sectors["Revenue"].sum()
# Out:
# Sector
# Aerospace & Defense              357940
# Apparel                           95968
# Business Services                272195
# Chemicals                        243897
# Energy                          1517809
# Engineering & Construction       153983
# Financials                      2217159
# Food and Drug Stores             483769
# Food, Beverages & Tobacco        555967
# Health Care                     1614707
# Hotels, Resturants & Leisure     169546
# Household Products               234737
# Industrials                      497581
# Materials                        259145
# Media                            220764
# Motor Vehicles & Parts           482540
# Retailing                       1465076
# Technology                      1377600
# Telecommunications               461834
# Transportation                   408508
# Wholesalers                      444800
# Name: Revenue, dtype: int64

# %%
sectors["Employees"].sum()
# Out:
# Sector
# Aerospace & Defense              968057
# Apparel                          346397
# Business Services               1361050
# Chemicals                        463651
# Energy                          1188927
# Engineering & Construction       406708
# Financials                      3359948
# Food and Drug Stores            1395398
# Food, Beverages & Tobacco       1211632
# Health Care                     2678289
# Hotels, Resturants & Leisure    2484245
# Household Products               646038
# Industrials                     1545229
# Materials                        638123
# Media                            550314
# Motor Vehicles & Parts          1082560
# Retailing                       6227629
# Technology                      3578949
# Telecommunications               832468
# Transportation                  1536793
# Wholesalers                      525597
# Name: Employees, dtype: int64

# %%
sectors["Profits"].max()
# Out:
# Sector
# Aerospace & Defense              7608
# Apparel                          3273
# Business Services                6328
# Chemicals                        7685
# Energy                          16150
# Engineering & Construction        803
# Financials                      24442
# Food and Drug Stores             5237
# Food, Beverages & Tobacco        7351
# Health Care                     18108
# Hotels, Resturants & Leisure     5920
# Household Products               7036
# Industrials                      4833
# Materials                         991
# Media                            8382
# Motor Vehicles & Parts           9687
# Retailing                       14694
# Technology                      53394
# Telecommunications              17879
# Transportation                   7610
# Wholesalers                      1472
# Name: Profits, dtype: int64

# %%
sectors["Profits"].min()
# Out:
# Sector
# Aerospace & Defense              -240
# Apparel                            82
# Business Services               -1481
# Chemicals                        -816
# Energy                         -23119
# Engineering & Construction       -155
# Financials                      -1194
# Food and Drug Stores              -62
# Food, Beverages & Tobacco        -253
# Health Care                      -458
# Hotels, Resturants & Leisure    -1394
# Household Products              -1149
# Industrials                     -6126
# Materials                       -1642
# Media                            -881
# Motor Vehicles & Parts           -889
# Retailing                       -1243
# Technology                      -4359
# Telecommunications               -271
# Transportation                   -191
# Wholesalers                      -502
# Name: Profits, dtype: int64

# %%
sectors["Employees"].mean()
# Out:
# Sector
# Aerospace & Defense             48402.850000
# Apparel                         23093.133333
# Business Services               26687.254902
# Chemicals                       15455.033333
# Energy                           9745.303279
# Engineering & Construction      15642.615385
# Financials                      24172.287770
# Food and Drug Stores            93026.533333
# Food, Beverages & Tobacco       28177.488372
# Health Care                     35710.520000
# Hotels, Resturants & Leisure    99369.800000
# Household Products              23072.785714
# Industrials                     33591.934783
# Materials                       14840.069767
# Media                           22012.560000
# Motor Vehicles & Parts          45106.666667
# Retailing                       77845.362500
# Technology                      35087.735294
# Telecommunications              55497.866667
# Transportation                  42688.694444
# Wholesalers                     13139.925000
# ...

# %%
sectors[["Profits", "Revenue"]].mean()
# Out:
#                                   Profits       Revenue
# Sector
# Aerospace & Defense           1437.100000  17897.000000
# Apparel                        549.066667   6397.866667
# Business Services              553.470588   5337.156863
# Chemicals                      754.266667   8129.900000
# Energy                        -602.024590  12441.057377
# Engineering & Construction     204.000000   5922.423077
# Financials                    1872.007194  15950.784173
# Food and Drug Stores          1117.266667  32251.266667
# Food, Beverages & Tobacco     1195.744186  12929.465116
# Health Care                   1414.853333  21529.426667
# Hotels, Resturants & Leisure   827.880000   6781.840000
# Household Products             515.285714   8383.464286
# Industrials                    451.391304  10816.978261
# Materials                      102.976744   6026.627907
# Media                          973.880000   8830.560000
# Motor Vehicles & Parts        1079.083333  20105.833333
# ...

# %% [markdown]
# # GROUPIN BY MULTIPLE COLUMNS

# %%
df.head(3)
# Out:
#        Company      Sector                     Industry         Location  \
# 0      Walmart   Retailing        General Merchandisers  Bentonville, AR
# 1  Exxon Mobil      Energy           Petroleum Refining       Irving, TX
# 2        Apple  Technology  Computers, Office Equipment    Cupertino, CA
#
#    Revenue  Profits  Employees
# 0   482130    14694    2300000
# 1   246204    16150      75600
# 2   233715    53394     110000

# %%
sectors = df.groupby(["Sector", "Industry"])

# %%
sectors.size()
# Out:
# Sector               Industry
# Aerospace & Defense  Aerospace and Defense                            20
# Apparel              Apparel                                          15
# Business Services    Advertising, marketing                            2
#                      Diversified Outsourcing Services                 14
#                      Education                                         3
#                                                                       ..
# Transportation       Trucking, Truck Leasing                           9
# Wholesalers          Miscellaneous                                     1
#                      Wholesalers: Diversified                         25
#                      Wholesalers: Electronics and Office Equipment     8
#                      Wholesalers: Food and Grocery                     6
# Length: 79, dtype: int64

# %%
sectors.sum()
# Out:
#                                                                    Revenue  \
# Sector              Industry
# Aerospace & Defense Aerospace and Defense                           357940
# Apparel             Apparel                                          95968
# Business Services   Advertising, marketing                           22748
#                     Diversified Outsourcing Services                 64829
#                     Education                                         7485
# ...                                                                    ...
# Transportation      Trucking, Truck Leasing                          35950
# Wholesalers         Miscellaneous                                     8982
#                     Wholesalers: Diversified                        176138
#                     Wholesalers: Electronics and Office Equipment   147906
#                     Wholesalers: Food and Grocery                   111774
#
# ...

# %%
sectors["Revenue"].sum()
# Out:
# Sector               Industry
# Aerospace & Defense  Aerospace and Defense                            357940
# Apparel              Apparel                                           95968
# Business Services    Advertising, marketing                            22748
#                      Diversified Outsourcing Services                  64829
#                      Education                                          7485
#                                                                        ...
# Transportation       Trucking, Truck Leasing                           35950
# Wholesalers          Miscellaneous                                      8982
#                      Wholesalers: Diversified                         176138
#                      Wholesalers: Electronics and Office Equipment    147906
#                      Wholesalers: Food and Grocery                    111774
# Name: Revenue, Length: 79, dtype: int64

# %%
sectors["Employees"].mean()
# Out:
# Sector               Industry
# Aerospace & Defense  Aerospace and Defense                            48402.850000
# Apparel              Apparel                                          23093.133333
# Business Services    Advertising, marketing                           62050.000000
#                      Diversified Outsourcing Services                 50595.000000
#                      Education                                        15585.000000
#                                                                           ...
# Transportation       Trucking, Truck Leasing                          18939.555556
# Wholesalers          Miscellaneous                                     9200.000000
#                      Wholesalers: Diversified                          9353.240000
#                      Wholesalers: Electronics and Office Equipment    20832.625000
#                      Wholesalers: Food and Grocery                    19317.500000
# ...

# %%
df = pd.read_csv('Fortune1000.csv')

# %%
df.head(3)
# Out:
#    Rank      Company      Sector                     Industry  \
# 0     1      Walmart   Retailing        General Merchandisers
# 1     2  Exxon Mobil      Energy           Petroleum Refining
# 2     3        Apple  Technology  Computers, Office Equipment
#
#           Location  Revenue  Profits  Employees
# 0  Bentonville, AR   482130    14694    2300000
# 1       Irving, TX   246204    16150      75600
# 2    Cupertino, CA   233715    53394     110000

# %%
df = pd.read_csv('fortune1000.csv', index_col="Rank")

# %%
df
# Out:
#                          Company                        Sector  \
# Rank
# 1                        Walmart                     Retailing
# 2                    Exxon Mobil                        Energy
# 3                          Apple                    Technology
# 4             Berkshire Hathaway                    Financials
# 5                       McKesson                   Health Care
# ...                          ...                           ...
# 996   New York Community Bancorp                    Financials
# 997    Portland General Electric                        Energy
# 997    Portland General Electric                        Energy
# 999                      Wendy’s  Hotels, Resturants & Leisure
# 1000           Briggs & Stratton                   Industrials
#
#                                       Industry           Location  Revenue  \
# Rank
# 1                        General Merchandisers    Bentonville, AR   482130
# ...
