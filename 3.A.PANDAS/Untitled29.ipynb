# %%
import pandas as pd
df = pd.read_csv('nba.csv')

# %%
df.head(3)
# Out:
#             Name            Team  Number Position   Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0  06-Feb   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0  06-Jun   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0  06-May   205.0
#
#              College     Salary  Bonus  Sales
# 0              Texas  7730337.0    NaN    NaN
# 1          Marquette  6796117.0    NaN    NaN
# 2  Boston University        NaN    NaN    NaN

# %%
new = df["Height"].str.split("-", n = 1, expand = True) 
  
# making separate first name column from new data frame 
df["h1"]= new[0] 
  
# making separate last name column from new data frame 
df["h2"]= new[1]

# %%
df.head(3)
# Out:
#             Name            Team  Number Position   Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0  06-Feb   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0  06-Jun   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0  06-May   205.0
#
#              College     Salary  Bonus  Sales  h1   h2
# 0              Texas  7730337.0    NaN    NaN  06  Feb
# 1          Marquette  6796117.0    NaN    NaN  06  Jun
# 2  Boston University        NaN    NaN    NaN  06  May

# %%
d = {'JAN':1, 'FEB':2, 'MAR':3, 'APR':4,'May':5,'Jun':6,'Jul':7,'Aug':8,'Sep':9,'Oct':10,'Nov':11,'0':12 }

# %%
df['h2'] = df['h2'].map(d)

# %%
df.head(3)
# Out:
#             Name            Team  Number Position   Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0  06-Feb   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0  06-Jun   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0  06-May   205.0
#
#              College     Salary  Bonus  Sales  h1   h2
# 0              Texas  7730337.0    NaN    NaN  06  NaN
# 1          Marquette  6796117.0    NaN    NaN  06  6.0
# 2  Boston University        NaN    NaN    NaN  06  5.0

# %%
df = df.dropna(axis=0,how='all')

# %%
df = df.dropna(axis=1,how='all')

# %%
df['h2'].value_counts()
# Out:
# 9.0     60
# 10.0    46
# 7.0     45
# 11.0    43
# 8.0     43
# 6.0     42
# 12.0    37
# 5.0     32
# Name: h2, dtype: int64

# %%
df.isnull().sum()
# Out:
# Name          1
# Team          1
# Number        1
# Position      1
# Age           1
# Height        1
# Weight        1
# College      85
# Salary       12
# Bonus       457
# Sales       457
# h1            1
# h2            1
# dtype: int64

# %%
df.head(20)
# Out:
#                        Name            Team  Number Position   Age  Height  \
# 0             Avery Bradley  Boston Celtics     0.0       PG  25.0  06-Feb
# 1               Jae Crowder  Boston Celtics    99.0       SF  25.0  06-Jun
# 2              John Holland  Boston Celtics    30.0       SG  27.0  06-May
# 3               R.J. Hunter  Boston Celtics    28.0       SG  22.0  06-May
# 4             Jonas Jerebko  Boston Celtics     8.0       PF  29.0  06-Oct
# 5              Amir Johnson  Boston Celtics    90.0       PF  29.0  06-Sep
# 6             Jordan Mickey  Boston Celtics    55.0       PF  21.0  06-Aug
# 7              Kelly Olynyk  Boston Celtics    41.0        C  25.0     7-0
# 8              Terry Rozier  Boston Celtics    12.0       PG  22.0  06-Feb
# 9              Marcus Smart  Boston Celtics    36.0       PG  22.0  06-Apr
# 10          Jared Sullinger  Boston Celtics     7.0        C  24.0  06-Sep
# ...

# %%
df
# Out:
#               Name            Team  Number Position   Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0  06-Feb   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0  06-Jun   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0  06-May   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0  06-May   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0  06-Oct   231.0
# ..             ...             ...     ...      ...   ...     ...     ...
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0  06-Jun   206.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0  06-Mar   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0  06-Jan   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0  07-Mar   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0     7-0   231.0
#
#                College     Salary  h1    h2
# ...

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (281, 11)

# %%
df['h1'] = df['h1'].astype(str)
# Out:
# <ipython-input-47-30581dc9ac48>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['h1'] = df['h1'].astype(str)

# %%
df['h2'] = df['h2'].astype(str)
# Out:
# <ipython-input-48-cb8847f03fe7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['h2'] = df['h2'].astype(str)

# %%
df['Correct_Height'] = df['h1'].str.cat(df['h2'],sep=".")
# Out:
# <ipython-input-50-e0949ba193c6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Correct_Height'] = df['h1'].str.cat(df['h2'],sep=".")

# %%
df
# Out:
#                 Name            Team  Number Position   Age  Height  Weight  \
# 1        Jae Crowder  Boston Celtics    99.0       SF  25.0  06-Jun   235.0
# 3        R.J. Hunter  Boston Celtics    28.0       SG  22.0  06-May   185.0
# 6      Jordan Mickey  Boston Celtics    55.0       PF  21.0  06-Aug   235.0
# 7       Kelly Olynyk  Boston Celtics    41.0        C  25.0     7-0   238.0
# 10   Jared Sullinger  Boston Celtics     7.0        C  24.0  06-Sep   260.0
# ..               ...             ...     ...      ...   ...     ...     ...
# 446   Derrick Favors       Utah Jazz    15.0       PF  24.0  06-Oct   265.0
# 448   Gordon Hayward       Utah Jazz    20.0       SF  26.0  06-Aug   226.0
# 449      Rodney Hood       Utah Jazz     5.0       SG  23.0  06-Aug   206.0
# 451    Chris Johnson       Utah Jazz    23.0       SF  26.0  06-Jun   206.0
# 456      Jeff Withey       Utah Jazz    24.0        C  26.0     7-0   231.0
#
#            College      Salary h1  h2 Correct_Height
# ...
