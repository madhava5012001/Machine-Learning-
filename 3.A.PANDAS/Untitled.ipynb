# %%
import pandas as pd

# %%
df = pd.read_csv('fortune1000.csv')

# %%
df.head(5)
# Out:
#    Rank             Company       Sector  \
# 0     1             Walmart    Retailing
# 1     2         Exxon Mobil       Energy
# 2     3               Apple   Technology
# 3     4  Berkshire Hathaway   Financials
# 4     5            McKesson  Health Care
#
#                                    Industry           Location  Revenue  \
# 0                     General Merchandisers    Bentonville, AR   482130
# 1                        Petroleum Refining         Irving, TX   246204
# 2               Computers, Office Equipment      Cupertino, CA   233715
# 3  Insurance: Property and Casualty (Stock)          Omaha, NE   210821
# 4                  Wholesalers: Health Care  San Francisco, CA   181241
#
#    Profits  Employees
# 0    14694    2300000
# 1    16150      75600
# 2    53394     110000
# 3    24083     331000
# 4     1476      70400

# %%
df.tail(5)
# Out:
#      Rank                     Company                        Sector  \
# 995   996  New York Community Bancorp                    Financials
# 996   997   Portland General Electric                        Energy
# 997   997   Portland General Electric                        Energy
# 998   999                     Wendy’s  Hotels, Resturants & Leisure
# 999  1000           Briggs & Stratton                   Industrials
#
#                         Industry       Location  Revenue  Profits  Employees
# 995             Commercial Banks   Westbury, NY     1902      -47       3448
# 996  Utilities: Gas and Electric   Portland, OR     1898      172       2646
# 997  Utilities: Gas and Electric   Portland, OR     1898      172       2646
# 998                Food Services     Dublin, OH     1896      161      21200
# 999         Industrial Machinery  Wauwatosa, WI     1895       46       5480

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # GROUP BY

# %%
sectorsgrouped = df.groupby('Sector')

# %%
type(sectorsgrouped)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
len(sectorsgrouped)
# Out:
# 21

# %%
len(df)
# Out:
# 1000

# %%
df['Sector'].nunique()
# Out:
# 21

# %%
sectorsgrouped.size()
# Out:
# Sector
# Aerospace & Defense              20
# Apparel                          15
# Business Services                51
# Chemicals                        30
# Energy                          122
# Engineering & Construction       26
# Financials                      139
# Food and Drug Stores             15
# Food, Beverages & Tobacco        43
# Health Care                      75
# Hotels, Resturants & Leisure     25
# Household Products               28
# Industrials                      46
# Materials                        43
# Media                            25
# Motor Vehicles & Parts           24
# Retailing                        80
# Technology                      102
# Telecommunications               15
# Transportation                   36
# Wholesalers                      40
# dtype: int64

# %%
sectorsgrouped

# %%
sectorsgrouped.head(3)
# Out:
#      Rank                   Company                        Sector  \
# 0       1                   Walmart                     Retailing
# 1       2               Exxon Mobil                        Energy
# 2       3                     Apple                    Technology
# 3       4        Berkshire Hathaway                    Financials
# 4       5                  McKesson                   Health Care
# ..    ...                       ...                           ...
# 194   195    Marriott International  Hotels, Resturants & Leisure
# 198   199                   Aramark             Business Services
# 230   231                        VF                       Apparel
# 234   235  Jacobs Engineering Group    Engineering & Construction
# 339   340                       PVH                       Apparel
#
#                                      Industry           Location  Revenue  \
# 0                       General Merchandisers    Bentonville, AR   482130
# ...

# %%
sectorsgrouped.max()
# Out:
#                               Rank                 Company  \
# Sector
# Aerospace & Defense            987                Woodward
# Apparel                        917    Wolverine World Wide
# Business Services              993           Western Union
# Chemicals                      949       Westlake Chemical
# Energy                         997             Xcel Energy
# Engineering & Construction     994            Tutor Perini
# Financials                     996          Zions Bancorp.
# Food and Drug Stores           928      Whole Foods Market
# Food, Beverages & Tobacco      954         WhiteWave Foods
# Health Care                    978         inVentiv Health
# Hotels, Resturants & Leisure   999              Yum Brands
# Household Products             992           Vista Outdoor
# Industrials                   1000      Zebra Technologies
# Materials                      986  Worthington Industries
# Media                          989             iHeartMedia
# ...

# %%
sectorsgrouped.head()
# Out:
#      Rank             Company                      Sector  \
# 0       1             Walmart                   Retailing
# 1       2         Exxon Mobil                      Energy
# 2       3               Apple                  Technology
# 3       4  Berkshire Hathaway                  Financials
# 4       5            McKesson                 Health Care
# ..    ...                 ...                         ...
# 260   261        Estee Lauder          Household Products
# 300   301              Lennar  Engineering & Construction
# 339   340                 PVH                     Apparel
# 353   354        Ralph Lauren                     Apparel
# 447   448         Hanesbrands                     Apparel
#
#                                      Industry           Location  Revenue  \
# 0                       General Merchandisers    Bentonville, AR   482130
# 1                          Petroleum Refining         Irving, TX   246204
# ...

# %%
SectorIndustry = df.groupby('Industry')

# %%
df.columns
# Out:
# Index(['Rank', 'Company', 'Sector', 'Industry', 'Location', 'Revenue',
#        'Profits', 'Employees'],
#       dtype='object')

# %%
SectorIndustry[['Employees']].max()
# Out:
#                                                Employees
# Industry
# Advertising, marketing                             74900
# Aerospace and Defense                             197200
# Airlines                                          118500
# Apparel                                            65300
# Automotive Retailing, Services                     30000
# ...                                                  ...
# Waste Management                                   40600
# Wholesalers: Diversified                           39600
# Wholesalers: Electronics and Office Equipment      78500
# Wholesalers: Food and Grocery                      51700
# Wholesalers: Health Care                           70400
#
# [73 rows x 1 columns]

# %%
SectorIndustry[['Profits','Revenue']].max()
# Out:
#                                                Profits  Revenue
# Industry
# Advertising, marketing                            1094    15134
# Aerospace and Defense                             7608    96114
# Airlines                                          7610    40990
# Apparel                                           3273    30601
# Automotive Retailing, Services                     597    20862
# ...                                                ...      ...
# Waste Management                                   753    12961
# Wholesalers: Diversified                          1472    30380
# Wholesalers: Electronics and Office Equipment      572    43026
# Wholesalers: Food and Grocery                      687    48681
# Wholesalers: Health Care                          1476   181241
#
# [73 rows x 2 columns]

# %%
SectorIndustry.head()
# Out:
#      Rank                            Company                     Sector  \
# 0       1                            Walmart                  Retailing
# 1       2                        Exxon Mobil                     Energy
# 2       3                              Apple                 Technology
# 3       4                 Berkshire Hathaway                 Financials
# 4       5                           McKesson                Health Care
# ..    ...                                ...                        ...
# 950   951                      On Assignment          Business Services
# 953   954         Alliance One International  Food, Beverages & Tobacco
# 971   972                  Genesee & Wyoming             Transportation
# 973   974  Roadrunner Transportation Systems             Transportation
# 992   993              DeVry Education Group          Business Services
#
#                                      Industry           Location  Revenue  \
# ...

# %%
industrygrp=df.groupby('Industry')

# %%
industrygrp[['Profits']].max()
# Out:
#                                                Profits
# Industry
# Advertising, marketing                            1094
# Aerospace and Defense                             7608
# Airlines                                          7610
# Apparel                                           3273
# Automotive Retailing, Services                     597
# ...                                                ...
# Waste Management                                   753
# Wholesalers: Diversified                          1472
# Wholesalers: Electronics and Office Equipment      572
# Wholesalers: Food and Grocery                      687
# Wholesalers: Health Care                          1476
#
# [73 rows x 1 columns]
