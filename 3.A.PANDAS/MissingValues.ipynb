# %%
import pandas as pd 
import numpy as np 
# importing the KNN from fancyimpute library 
from fancyimpute import KNN
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-1b2f699219bf> in <module>
#       2 import numpy as np
#       3 # importing the KNN from fancyimpute library
# ----> 4 from fancyimpute import KNN
#
# ModuleNotFoundError: No module named 'fancyimpute'

# %%
# !pip install fancyimpute
# Out:
# Processing c:\users\hp\appdata\local\pip\cache\wheels\fc\a1\09\732183800f7c813b6698e5a15bf1b47d52b037ec76d7277aa5\fancyimpute-0.5.5-py3-none-any.whl
# ...
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\hp\Anaconda0312\python.exe' 'C:\Users\hp\Anaconda0312\lib\site-packages\pip\_vendor\pep517\_in_process.py' build_wheel 'C:\Users\hp\AppData\Local\Temp\tmp1ajqghbv'
#   Using cached tensorflow-2.3.1-cp38-cp38-win_amd64.whl (342.5 MB)
# ...
#   Using cached cvxpy-1.1.7.tar.gz (1.0 MB)
#   Installing build dependencies: started
#   Installing build dependencies: still running...
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# ...
#   Using cached Keras-2.4.3-py2.py3-none-any.whl (36 kB)
# ...
